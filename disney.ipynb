# %%
#Importing Dependencies
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # Extracting Data

# %%
#Importing the JSON file (The whole Raw data)
json_file = "D:/ETL/Project/disney_movies.json"
json_movies = pd.read_json(json_file)

#Listing all the columns in the json file
json_movies.columns
# Out:
# Index(['title', 'Production company', 'Release date', 'Running time',
#        'Country', 'Language', 'Box office', 'Running time (int)',
#        'Budget (float)', 'Box office (float)', 'Release date (datetime)',
#        'imdb_rating', 'imdb_votes', 'imdb_id', 'metascore', 'rotten_tomatoes',
#        'Directed by', 'Produced by', 'Written by', 'Based on', 'Starring',
#        'Music by', 'Distributed by', 'Budget', 'Story by', 'Narrated by',
#        'Cinematography', 'Edited by', 'Screenplay by', 'Production companies',
#        'Japanese', 'Hepburn', 'Adaptation by', 'Traditional', 'Simplified'],
#       dtype='object')

# %%
#Extracting only the Columns needed for the Base Table
movies_df = json_movies[['title', 'Release date','Directed by', 'imdb_rating' ,'Running time',
                         'Budget (float)']].copy()
movies_df.head()
movies_df.columns
# Out:
# Index(['title', 'Release date', 'Directed by', 'imdb_rating', 'Running time',
#        'Budget (float)'],
#       dtype='object')

# %%
csv_file1 = "D:/ETL/Project/disney_movies.csv"
csv_movies1 = pd.read_csv(csv_file1)
csv_movies1.columns
# Out:
# Index(['movie_title', 'release_date', 'genre', 'mpaa_rating', 'total_gross',
#        'inflation_adjusted_gross'],
#       dtype='object')

# %%
csv_file1 = "D:/ETL/Project/disney-characters.csv"
characters_df = pd.read_csv(csv_file1)
characters_df.head()
# Out:
#                          movie_title       release_date        hero  \
# 0  \nSnow White and the Seven Dwarfs  December 21, 1937  Snow White
# 1                        \nPinocchio   February 7, 1940   Pinocchio
# 2                         \nFantasia  November 13, 1940         NaN
# 3                              Dumbo   October 23, 1941       Dumbo
# 4                            \nBambi    August 13, 1942       Bambi
#
#       villian                          song
# 0  Evil Queen  Some Day My Prince Will Come
# 1   Stromboli     When You Wish upon a Star
# 2   Chernabog                           NaN
# 3  Ringmaster                     Baby Mine
# 4      Hunter                Love Is a Song

# %%
csv_file2 = "D:/ETL/Project/disney-voice-actors.csv"
csv_movies3 = pd.read_csv(csv_file2)
csv_movies3.head()
# Out:
#         character      voice-actor                        movie
# 0    Abby Mallard      Joan Cusack               Chicken Little
# 1  Abigail Gabble     Monica Evans               The Aristocats
# 2        Abis Mal  Jason Alexander          The Return of Jafar
# 3             Abu     Frank Welker                      Aladdin
# 4        Achilles             None  The Hunchback of Notre Dame

# %% [markdown]
# # Cleaning the Data

# %%
#Renaming the Column Names
movies_df = movies_df.rename(columns={'title': 'Title', 'Release date': 'Release_Date','Directed by': 'Director', 'Running time': 'Run Time(mins)',
                          'Budget (float)':'Budget (USD in Millions)', 'imdb_rating' :'IMDB Rating' } )
movies_df.head()
# Out:
#                              Title  \
# 0          Academy Award Review of
# 1  Snow White and the Seven Dwarfs
# 2                        Pinocchio
# 3                         Fantasia
# 4             The Reluctant Dragon
#
#                                         Release_Date  \
# 0                                     [May 19, 1937]
# 1  [December 21, 1937 ( Carthay Circle Theatre , ...
# 2  [February 7, 1940 ( Center Theatre ), February...
# 3                                [November 13, 1940]
# 4                                    [June 20, 1941]
#
#                                             Director IMDB Rating  \
# 0                                                NaN         7.2
# 1  [David Hand (supervising), William Cottrell, W...         7.6
# 2  [Ben Sharpsteen, Hamilton Luske, Bill Roberts,...         7.4
# 3  [Samuel Armstrong, James Algar, Bill Roberts, ...         7.8
# 4  [Alfred Werker, (live action), Hamilton Luske,...         6.9
#
#                          Run Time(mins)  Budget (USD in Millions)
# 0  41 minutes (74 minutes 1966 release)                       NaN
# 1                            83 minutes                 1490000.0
# 2                            88 minutes                 2600000.0
# 3                           126 minutes                 2280000.0
# 4                            74 minutes                  600000.0

# %%
#Formatting the Release Date column
movies_df['Release_Date' ] = movies_df['Release_Date'].str[0]
new_df  = movies_df["Release_Date"].str.split("(", n = 1, expand = True)
movies_df["Release_Date"] = new_df[0]
movies_df.head()
# Out:
#                              Title        Release_Date  \
# 0          Academy Award Review of        May 19, 1937
# 1  Snow White and the Seven Dwarfs  December 21, 1937
# 2                        Pinocchio   February 7, 1940
# 3                         Fantasia   November 13, 1940
# 4             The Reluctant Dragon       June 20, 1941
#
#                                             Director IMDB Rating  \
# 0                                                NaN         7.2
# 1  [David Hand (supervising), William Cottrell, W...         7.6
# 2  [Ben Sharpsteen, Hamilton Luske, Bill Roberts,...         7.4
# 3  [Samuel Armstrong, James Algar, Bill Roberts, ...         7.8
# 4  [Alfred Werker, (live action), Hamilton Luske,...         6.9
#
#                          Run Time(mins)  Budget (USD in Millions)
# 0  41 minutes (74 minutes 1966 release)                       NaN
# 1                            83 minutes                 1490000.0
# 2                            88 minutes                 2600000.0
# 3                           126 minutes                 2280000.0
# 4                            74 minutes                  600000.0

# %%
#Formatting the movie_title Column in Characters_df to remove '\n' Characters
characters_df['movie_title']=  characters_df['movie_title'].str.replace('\n', '')
characters_df.columns
# Out:
# Index(['movie_title', 'release_date', 'hero', 'villian', 'song'], dtype='object')

# %% [markdown]
# # Transforming Data

# %%
#Merging two dataframes to put together basic information of each movie
basic_df = movies_df.merge(csv_movies1, left_on = 'Title', right_on = 'movie_title' )

#Viewing the whole merged dataframe
basic_df.head(2)
# Out:
#                              Title        Release_Date  \
# 0  Snow White and the Seven Dwarfs  December 21, 1937
# 1                        Pinocchio   February 7, 1940
#
#                                             Director IMDB Rating  \
# 0  [David Hand (supervising), William Cottrell, W...         7.6
# 1  [Ben Sharpsteen, Hamilton Luske, Bill Roberts,...         7.4
#
#   Run Time(mins)  Budget (USD in Millions)                      movie_title  \
# 0     83 minutes                 1490000.0  Snow White and the Seven Dwarfs
# 1     88 minutes                 2600000.0                        Pinocchio
#
#   release_date      genre mpaa_rating  total_gross  inflation_adjusted_gross
# 0   1937-12-21    Musical           G    184925485                5228953251
# 1   1940-02-09  Adventure           G     84300000                2188229052

# %%
#Viewing the columns of merged dataframe to grab the ones that are required
basic_df.columns
# Out:
# Index(['Title', 'Release_Date', 'Director', 'IMDB Rating', 'Run Time(mins)',
#        'Budget (USD in Millions)', 'movie_title', 'release_date', 'genre',
#        'mpaa_rating', 'total_gross', 'inflation_adjusted_gross'],
#       dtype='object')

# %%
#Extracting only the relevant columns
basic_df = basic_df[['Title', 'Release_Date', 'Director','Run Time(mins)', 'mpaa_rating']]
basic_df
# Out:
#                                Title         Release_Date  \
# 0    Snow White and the Seven Dwarfs   December 21, 1937
# 1                          Pinocchio    February 7, 1940
# 2                           Fantasia    November 13, 1940
# 3                  Song of the South   November 12, 1946
# 4                         Cinderella   February 15, 1950
# ..                               ...                  ...
# 229  Alice Through the Looking Glass        May 10, 2016
# 230                     Finding Dory        June 8, 2016
# 231                          The BFG        May 14, 2016
# 232                   Queen of Katwe  September 10, 2016
# 233                            Moana   November 14, 2016
#
#                                               Director Run Time(mins)  \
# 0    [David Hand (supervising), William Cottrell, W...     83 minutes
# 1    [Ben Sharpsteen, Hamilton Luske, Bill Roberts,...     88 minutes
# 2    [Samuel Armstrong, James Algar, Bill Roberts, ...    126 minutes
# 3    [Live action:, Harve Foster, Animation:, Wilfr...     94 minutes
# 4    [Clyde Geronimi, Hamilton Luske, Wilfred Jackson]     74 minutes
# ..                                                 ...            ...
# 229                                        James Bobin    114 minutes
# 230                                     Andrew Stanton     97 minutes
# 231                                   Steven Spielberg    117 minutes
# 232                                          Mira Nair    124 minutes
# 233                        [Ron Clements, John Musker]    107 minutes
#
#     mpaa_rating
# 0             G
# 1             G
# 2             G
# 3             G
# 4             G
# ..          ...
# 229          PG
# 230          PG
# 231          PG
# 232          PG
# 233          PG
#
# [234 rows x 5 columns]

# %%
json_movies.columns
# Out:
# Index(['title', 'Production company', 'Release date', 'Running time',
#        'Country', 'Language', 'Box office', 'Running time (int)',
#        'Budget (float)', 'Box office (float)', 'Release date (datetime)',
#        'imdb_rating', 'imdb_votes', 'imdb_id', 'metascore', 'rotten_tomatoes',
#        'Directed by', 'Produced by', 'Written by', 'Based on', 'Starring',
#        'Music by', 'Distributed by', 'Budget', 'Story by', 'Narrated by',
#        'Cinematography', 'Edited by', 'Screenplay by', 'Production companies',
#        'Japanese', 'Hepburn', 'Adaptation by', 'Traditional', 'Simplified'],
#       dtype='object')
